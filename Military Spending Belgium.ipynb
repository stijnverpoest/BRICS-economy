# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Stijn\Documents\GitHub\Military-Spending

# %%
df = pd.read_csv("Military Expenditure.csv", index_col=1)
df.head()
# Out:
#              Name     Type                      Indicator Name  1960  1961  \
# Code
# ABW         Aruba  Country  Military expenditure (current USD)   NaN   NaN
# AFG   Afghanistan  Country  Military expenditure (current USD)   NaN   NaN
# AGO        Angola  Country  Military expenditure (current USD)   NaN   NaN
# ALB       Albania  Country  Military expenditure (current USD)   NaN   NaN
# AND       Andorra  Country  Military expenditure (current USD)   NaN   NaN
#
#       1962  1963  1964  1965  1966  ...          2009          2010  \
# Code                                ...
# ABW    NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# AFG    NaN   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08
# AGO    NaN   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09
# ALB    NaN   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08
# AND    NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
#               2011          2012          2013          2014          2015  \
# Code
# ABW            NaN           NaN           NaN           NaN           NaN
# AFG   3.258070e+08  2.385834e+08  2.171941e+08  2.682271e+08  1.995186e+08
# AGO   3.639496e+09  4.144635e+09  6.090752e+09  6.841864e+09  3.608299e+09
# ALB   1.970068e+08  1.832047e+08  1.800155e+08  1.781204e+08  1.323507e+08
# AND            NaN           NaN           NaN           NaN           NaN
#
#               2016          2017          2018
# Code
# ABW            NaN           NaN           NaN
# AFG   1.858783e+08  1.914071e+08  1.980863e+08
# AGO   2.764055e+09  3.062873e+09  1.983614e+09
# ALB   1.308532e+08  1.443827e+08  1.804887e+08
# AND            NaN           NaN           NaN
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  7.900000e+01  8.400000e+01  9.300000e+01  9.800000e+01  9.800000e+01
# mean   4.482374e+09  4.450649e+09  4.520297e+09  4.462435e+09  4.525730e+09
# std    1.447959e+10  1.486998e+10  1.560037e+10  1.551553e+10  1.552208e+10
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.205030e+07  2.571702e+07  2.484204e+07  2.866130e+07  3.662134e+07
# 50%    1.408889e+08  1.200573e+08  1.700342e+08  1.824402e+08  1.891038e+08
# 75%    8.240486e+08  7.590874e+08  8.332295e+08  8.987564e+08  1.144744e+09
# max    6.777699e+10  7.161496e+10  7.889139e+10  8.097281e+10  8.148150e+10
#
#                1965          1966          1967          1968          1969  \
# count  1.040000e+02  1.040000e+02  1.050000e+02  1.130000e+02  1.130000e+02
# mean   4.429380e+09  5.098436e+09  5.757744e+09  5.661456e+09  5.866198e+09
# std    1.544076e+10  1.817987e+10  2.092876e+10  2.133673e+10  2.175941e+10
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.396381e+07  3.803623e+07  3.554479e+07  2.040000e+07  2.286154e+07
# 50%    2.048374e+08  2.388078e+08  2.519307e+08  2.727273e+08  2.636364e+08
# 75%    8.919075e+08  1.009040e+09  1.123833e+09  1.119925e+09  1.380000e+09
# max    8.364532e+10  9.752720e+10  1.120000e+11  1.180000e+11  1.210000e+11
#
#        ...          2009          2010          2011          2012  \
# count  ...  1.970000e+02  1.960000e+02  1.940000e+02  1.990000e+02
# mean   ...  5.919239e+10  6.289206e+10  6.823127e+10  6.767465e+10
# std    ...  1.976434e+11  2.067953e+11  2.188292e+11  2.152426e+11
# min    ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...  2.148242e+08  2.195343e+08  2.592131e+08  2.309348e+08
# 50%    ...  2.115785e+09  2.136473e+09  2.484600e+09  2.589776e+09
# 75%    ...  1.783128e+10  1.682419e+10  1.823214e+10  1.875641e+10
# max    ...  1.550000e+12  1.630000e+12  1.730000e+12  1.740000e+12
#
#                2013          2014          2015          2016          2017  \
# count  2.020000e+02  2.030000e+02  1.980000e+02  1.970000e+02  1.950000e+02
# mean   6.782427e+10  6.788223e+10  6.553286e+10  6.562135e+10  6.927640e+10
# std    2.112636e+11  2.095356e+11  2.002215e+11  2.008000e+11  2.091964e+11
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.510677e+08  2.491632e+08  2.488889e+08  2.607297e+08  2.851254e+08
# 50%    2.435637e+09  2.355992e+09  2.415996e+09  2.455784e+09  2.328157e+09
# 75%    1.937015e+10  2.031822e+10  1.927764e+10  1.785398e+10  2.147698e+10
# max    1.740000e+12  1.740000e+12  1.640000e+12  1.630000e+12  1.700000e+12
#
#                2018
# count  1.960000e+02
# mean   7.216267e+10
# std    2.202652e+11
# min    0.000000e+00
# 25%    2.945764e+08
# 50%    2.406164e+09
# 75%    1.832208e+10
# max    1.780000e+12
#
# [8 rows x 59 columns]

# %%
df_belgium = df[df['Name']=='Belgium']
df_belgium.head()
# Out:
#          Name     Type                      Indicator Name         1960  \
# Code
# BEL   Belgium  Country  Military expenditure (current USD)  383220247.4
#
#              1961         1962         1963         1964         1965  \
# Code
# BEL   391218827.4  422220787.9  444601321.5  497059226.9  500722082.8
#
#              1966  ...          2009          2010          2011  \
# Code               ...
# BEL   563377895.4  ...  5.620670e+09  5.244721e+09  5.499371e+09
#
#               2012          2013          2014          2015          2016  \
# Code
# BEL   5.168998e+09  5.263165e+09  5.191509e+09  4.202063e+09  4.314102e+09
#
#               2017          2018
# Code
# BEL   4.484653e+09  4.959692e+09
#
# [1 rows x 62 columns]

# %%
df_belgium_years = df_belgium.iloc[:,3:]
df_belgium_years.head()
# Out:
#              1960         1961         1962         1963         1964  \
# Code
# BEL   383220247.4  391218827.4  422220787.9  444601321.5  497059226.9
#
#              1965         1966         1967         1968         1969  ...  \
# Code                                                                   ...
# BEL   500722082.8  563377895.4  607918707.2  646381114.5  675078864.4  ...
#
#               2009          2010          2011          2012          2013  \
# Code
# BEL   5.620670e+09  5.244721e+09  5.499371e+09  5.168998e+09  5.263165e+09
#
#               2014          2015          2016          2017          2018
# Code
# BEL   5.191509e+09  4.202063e+09  4.314102e+09  4.484653e+09  4.959692e+09
#
# [1 rows x 59 columns]

# %%
df_belgium_years_rows = df_belgium_years.melt(var_name = "year", value_name = "expenses")
df_belgium_years_rows.head(15)
# Out:
#     year      expenses
# 0   1960  3.832202e+08
# 1   1961  3.912188e+08
# 2   1962  4.222208e+08
# 3   1963  4.446013e+08
# 4   1964  4.970592e+08
# 5   1965  5.007221e+08
# 6   1966  5.633779e+08
# 7   1967  6.079187e+08
# 8   1968  6.463811e+08
# 9   1969  6.750789e+08
# 10  1970  7.477551e+08
# 11  1971  8.287216e+08
# 12  1972  1.026588e+09
# 13  1973  1.296520e+09
# 14  1974  1.482318e+09

# %%
tick_val= [0,1000000000,2000000000,3000000000,4000000000,5000000000,6000000000,7000000000] 
tick_lab=['0B','1B','2B','3B','4B','5B','6B','7B']

plt.scatter(x=df_belgium_years_rows.year, y=df_belgium_years_rows.expenses, c='green')
#plt.yscale('log')
plt.xlabel("Years")
plt.ylabel("Expenditure (USD)")
plt.title("Military Expenditure of Belgium from 1960-2018")
plt.yticks(tick_val, tick_lab)
plt.xticks(['1960','1970','1980','1990','2000','2010','2018'])
plt.text(35, 1000000000, "Conscription Suspended", fontsize='7',c='red') #35 --> 1995
plt.grid(True)
plt.show()

# %%
plt.plot(df_belgium_years_rows.year, df_belgium_years_rows.expenses)
plt.show()

# %%
plt.hist(df['2018'], bins=15) #histogram of 2018 budgets
# Out:
# (array([174.,   3.,   5.,   4.,   3.,   3.,   0.,   0.,   0.,   2.,   1.,
#           0.,   0.,   0.,   1.]),
#  array([0.00000000e+00, 1.18666667e+11, 2.37333333e+11, 3.56000000e+11,
#         4.74666667e+11, 5.93333333e+11, 7.12000000e+11, 8.30666667e+11,
#         9.49333333e+11, 1.06800000e+12, 1.18666667e+12, 1.30533333e+12,
#         1.42400000e+12, 1.54266667e+12, 1.66133333e+12, 1.78000000e+12]),
#  <BarContainer object of 15 artists>)

# %%
plt.hist(df['1965'], bins=15) #histogram of 1965 budgets
# Out:
# (array([95.,  2.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  2.,  0.,  0.,  0.,
#          1.,  2.]),
#  array([0.00000000e+00, 5.57635439e+09, 1.11527088e+10, 1.67290632e+10,
#         2.23054176e+10, 2.78817720e+10, 3.34581264e+10, 3.90344808e+10,
#         4.46108352e+10, 5.01871896e+10, 5.57635439e+10, 6.13398983e+10,
#         6.69162527e+10, 7.24926071e+10, 7.80689615e+10, 8.36453159e+10]),
#  <BarContainer object of 15 artists>)

# %%
df_fr=df.loc[df['Name']=='France']
df_ge=df[df.Name == "Germany"]
df_lux=df[df.Name == "Luxembourg"]
df_nl=df[df.Name == "Netherlands"]

# %%
df_eu = df_belgium.append(df_fr)
df_eu = df_eu.append(df_ge)
df_eu = df_eu.append(df_lux)
df_eu = df_eu.append(df_nl)
df_eu.head()
# Out:
#              Name     Type                      Indicator Name          1960  \
# Code
# BEL       Belgium  Country  Military expenditure (current USD)  3.832202e+08
# FRA        France  Country  Military expenditure (current USD)  3.881220e+09
# DEU       Germany  Country  Military expenditure (current USD)  2.884518e+09
# LUX    Luxembourg  Country  Military expenditure (current USD)  5.260313e+06
# NLD   Netherlands  Country  Military expenditure (current USD)  4.547194e+08
#
#               1961          1962          1963          1964          1965  \
# Code
# BEL   3.912188e+08  4.222208e+08  4.446013e+08  4.970592e+08  5.007221e+08
# FRA   4.131004e+09  4.493324e+09  4.628061e+09  4.917957e+09  5.124507e+09
# DEU   3.266496e+09  4.308248e+09  4.981004e+09  4.888249e+09  4.978559e+09
# LUX   5.800866e+06  7.099970e+06  6.962653e+06  9.278159e+06  9.520198e+06
# NLD   5.515305e+08  6.038669e+08  6.373731e+08  7.353836e+08  7.499939e+08
#
#               1966  ...          2009          2010          2011  \
# Code                ...
# BEL   5.633779e+08  ...  5.620670e+09  5.244721e+09  5.499371e+09
# FRA   5.414602e+09  ...  6.688403e+10  6.178175e+10  6.460093e+10
# DEU   5.063638e+09  ...  4.747007e+10  4.625552e+10  4.814035e+10
# LUX   9.923596e+06  ...  2.229598e+08  2.741354e+08  2.569624e+08
# NLD   7.706918e+08  ...  1.213181e+10  1.122052e+10  1.164793e+10
#
#               2012          2013          2014          2015          2016  \
# Code
# BEL   5.168998e+09  5.263165e+09  5.191509e+09  4.202063e+09  4.314102e+09
# FRA   6.003515e+10  6.241710e+10  6.361357e+10  5.534213e+10  5.735841e+10
# DEU   4.647087e+10  4.593054e+10  4.610267e+10  3.981258e+10  4.157949e+10
# LUX   2.375030e+08  2.586559e+08  2.790190e+08  2.761451e+08  2.607297e+08
# NLD   1.036472e+10  1.022626e+10  1.033260e+10  8.667850e+09  9.115241e+09
#
#               2017          2018
# Code
# BEL   4.484653e+09  4.959692e+09
# FRA   6.041750e+10  6.379968e+10
# DEU   4.538172e+10  4.947063e+10
# LUX   3.576716e+08  4.193727e+08
# NLD   9.580685e+09  1.124276e+10
#
# [5 rows x 62 columns]

# %%
df_eu_years=df_eu.iloc[:,3:]
